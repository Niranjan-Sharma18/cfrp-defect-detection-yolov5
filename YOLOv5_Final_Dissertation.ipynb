# %%
# Import necessary libraries
from google.colab import drive
import scipy.io
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

# Mount Google Drive
drive.mount('/content/drive')

# Create the destination folder if it doesn't exist
output_dir = '/content/drive/My Drive/Colab Notebooks/thermal img dataset'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Path to your .mat files
mat_files_dir = '/content/drive/My Drive/Colab Notebooks/thermal cfrp data'

def save_3d_array_as_images(array, output_folder, prefix):
    """
    Save each 2D slice of a 3D array as an image
    array: 3D numpy array
    output_folder: destination folder path
    prefix: prefix for the image filenames
    """
    # Get the number of slices
    num_images = array.shape[0]

    for i in range(num_images):
        # Extract the 2D slice
        img_data = array[i, :, :]

        # Normalize to 0-255 range for PNG format
        img_data = ((img_data - img_data.min()) * (255.0 / (img_data.max() - img_data.min()))).astype(np.uint8)

        # Create image from array
        img = Image.fromarray(img_data)

        # Save the image
        img_path = os.path.join(output_folder, f'{prefix}_image_{i:04d}.png')
        img.save(img_path)

        # Print progress every 10 images
        if (i + 1) % 10 == 0:
            print(f'Saved {i + 1}/{num_images} images from {prefix}')

# Process each .mat file
mat_files = ['P1X1_train_norm.mat', 'P1X2_train_norm.mat',
             'P2X1_train_norm.mat', 'P2X2_train_norm.mat']

for filename in mat_files:
    mat_path = os.path.join(mat_files_dir, filename)
    if os.path.exists(mat_path):
        print(f'\nProcessing {filename}...')
        # Load the .mat file
        mat_data = scipy.io.loadmat(mat_path)

        # Print the keys in the .mat file
        print(f'Keys in {filename}:', mat_data.keys())

        # Find the main data array (excluding metadata keys that start with '__')
        data_keys = [key for key in mat_data.keys() if not key.startswith('__')]

        if data_keys:
            for key in data_keys:
                data_array = mat_data[key]
                print(f'Shape of array in {key}:', data_array.shape)

                # Save images
                prefix = filename.split('.')[0]
                save_3d_array_as_images(data_array, output_dir, prefix)
        else:
            print(f'No data arrays found in {filename}')
    else:
        print(f'File not found: {filename}')

print('\nImage extraction complete')

# Print total number of saved images
total_images = len([name for name in os.listdir(output_dir) if name.endswith('.png')])
print(f'\nTotal images saved: {total_images}')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Processing P1X1_train_norm.mat...
# Keys in P1X1_train_norm.mat: dict_keys(['__header__', '__version__', '__globals__', 'P1X1_train_norm'])
# Shape of array in P1X1_train_norm: (120, 250, 200)
# Saved 10/120 images from P1X1_train_norm
# Saved 20/120 images from P1X1_train_norm
# Saved 30/120 images from P1X1_train_norm
# Saved 40/120 images from P1X1_train_norm
# Saved 50/120 images from P1X1_train_norm
# Saved 60/120 images from P1X1_train_norm
# Saved 70/120 images from P1X1_train_norm
# Saved 80/120 images from P1X1_train_norm
# Saved 90/120 images from P1X1_train_norm
# Saved 100/120 images from P1X1_train_norm
# Saved 110/120 images from P1X1_train_norm
# Saved 120/120 images from P1X1_train_norm
#
# Processing P1X2_train_norm.mat...
# Keys in P1X2_train_norm.mat: dict_keys(['__header__', '__version__', '__globals__', 'P1X2_train_norm'])
# Shape of array in P1X2_train_norm: (120, 250, 200)
# Saved 10/120 images from P1X2_train_norm
# Saved 20/120 images from P1X2_train_norm
# Saved 30/120 images from P1X2_train_norm
# Saved 40/120 images from P1X2_train_norm
# Saved 50/120 images from P1X2_train_norm
# Saved 60/120 images from P1X2_train_norm
# Saved 70/120 images from P1X2_train_norm
# Saved 80/120 images from P1X2_train_norm
# Saved 90/120 images from P1X2_train_norm
# Saved 100/120 images from P1X2_train_norm
# Saved 110/120 images from P1X2_train_norm
# Saved 120/120 images from P1X2_train_norm
#
# Processing P2X1_train_norm.mat...
# Keys in P2X1_train_norm.mat: dict_keys(['__header__', '__version__', '__globals__', 'P2X1_train_norm'])
# Shape of array in P2X1_train_norm: (120, 250, 200)
# Saved 10/120 images from P2X1_train_norm
# Saved 20/120 images from P2X1_train_norm
# Saved 30/120 images from P2X1_train_norm
# Saved 40/120 images from P2X1_train_norm
# Saved 50/120 images from P2X1_train_norm
# Saved 60/120 images from P2X1_train_norm
# Saved 70/120 images from P2X1_train_norm
# Saved 80/120 images from P2X1_train_norm
# Saved 90/120 images from P2X1_train_norm
# Saved 100/120 images from P2X1_train_norm
# Saved 110/120 images from P2X1_train_norm
# Saved 120/120 images from P2X1_train_norm
#
# Processing P2X2_train_norm.mat...
# Keys in P2X2_train_norm.mat: dict_keys(['__header__', '__version__', '__globals__', 'P2X2_train_norm'])
# Shape of array in P2X2_train_norm: (120, 250, 200)
# Saved 10/120 images from P2X2_train_norm
# Saved 20/120 images from P2X2_train_norm
# Saved 30/120 images from P2X2_train_norm
# Saved 40/120 images from P2X2_train_norm
# Saved 50/120 images from P2X2_train_norm
# Saved 60/120 images from P2X2_train_norm
# Saved 70/120 images from P2X2_train_norm
# Saved 80/120 images from P2X2_train_norm
# Saved 90/120 images from P2X2_train_norm
# Saved 100/120 images from P2X2_train_norm
# Saved 110/120 images from P2X2_train_norm
# Saved 120/120 images from P2X2_train_norm
#
# Image extraction complete
#
# Total images saved: 480

# %%
import numpy as np
import cv2
from google.colab import drive
import os
from PIL import Image

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# Define input and output directories
input_dir = '/content/drive/My Drive/Colab Notebooks/thermal img dataset'
output_dir = '/content/drive/My Drive/Colab Notebooks/thermal img dataset gradientSubtraction'

# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

def apply_gradient_subtraction(image):
    # Convert to float32 for calculations
    img_float = image.astype(np.float32)

    # Calculate gradients using Sobel operators
    grad_x = cv2.Sobel(img_float, cv2.CV_32F, 1, 0, ksize=3)
    grad_y = cv2.Sobel(img_float, cv2.CV_32F, 0, 1, ksize=3)

    # Calculate gradient magnitude
    gradient = np.sqrt(grad_x**2 + grad_y**2)

    # Subtract gradient from original image
    result = img_float - gradient

    # Normalize result to 0-255 range
    result = ((result - result.min()) * (255.0 / (result.max() - result.min()))).astype(np.uint8)

    return result

# Process all images
for filename in os.listdir(input_dir):
    if filename.endswith('.png'):
        # Read image
        img_path = os.path.join(input_dir, filename)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        # Apply gradient subtraction
        processed_img = apply_gradient_subtraction(img)

        # Save processed image
        output_path = os.path.join(output_dir, f'grad_{filename}')
        cv2.imwrite(output_path, processed_img)

print("Gradient subtraction completed")

# Count processed images
total_processed = len([name for name in os.listdir(output_dir) if name.endswith('.png')])
print(f'Total images processed: {total_processed}')
# Out:
# Mounted at /content/drive
# Gradient subtraction completed
# Total images processed: 480

# %%
# !pip install fpdf2

import numpy as np
import cv2
import os
from PIL import Image
from fpdf import FPDF
import matplotlib.pyplot as plt
from datetime import datetime

def calculate_snr(img):
    """Calculate Signal-to-Noise Ratio"""
    img_float = img.astype(float)

    # Define ROI for signal
    threshold = np.mean(img_float) + np.std(img_float)
    signal_mask = img_float > threshold
    noise_mask = ~signal_mask

    if np.sum(signal_mask) > 0 and np.sum(noise_mask) > 0:
        signal_mean = np.mean(img_float[signal_mask])
        noise_std = np.std(img_float[noise_mask])
        snr = 20 * np.log10(signal_mean / noise_std)
    else:
        snr = 0

    return snr

def create_comparison_plot(original_img, processed_img, snr_orig, snr_proc, filename):
    """Create a comparison plot with SNR values"""
    plt.figure(figsize=(12, 5))

    # Plot original image
    plt.subplot(121)
    plt.imshow(original_img, cmap='gray')
    plt.title(f'Original (SNR: {snr_orig:.2f} dB)')
    plt.axis('off')

    # Plot processed image
    plt.subplot(122)
    plt.imshow(processed_img, cmap='gray')
    plt.title(f'Gradient Subtracted (SNR: {snr_proc:.2f} dB)')
    plt.axis('off')

    # Save plot
    plt.savefig(f'temp_{filename}.png', bbox_inches='tight', dpi=300)
    plt.close()

# Define directories
original_dir = '/content/drive/My Drive/Colab Notebooks/thermal img dataset'
processed_dir = '/content/drive/My Drive/Colab Notebooks/thermal img dataset gradientSubtraction'
output_dir = '/content/drive/My Drive/Colab Notebooks/analysis_results'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Create PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)

# Add title page
pdf.add_page()
pdf.set_font('Arial', 'B', 16)
pdf.cell(0, 10, 'Thermal Image SNR Analysis Report', ln=True, align='C')
pdf.set_font('Arial', '', 12)
pdf.cell(0, 10, f'Generated on {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}', ln=True, align='C')

# Initialize lists to store metrics
all_metrics = []
filenames = []

# Process all images
print("Processing images...")
for filename in sorted(os.listdir(original_dir)):
    if filename.endswith('.png'):
        # Read images
        original_path = os.path.join(original_dir, filename)
        processed_path = os.path.join(processed_dir, f'grad_{filename}')

        if os.path.exists(processed_path):
            original_img = cv2.imread(original_path, cv2.IMREAD_GRAYSCALE)
            processed_img = cv2.imread(processed_path, cv2.IMREAD_GRAYSCALE)

            # Calculate SNR
            snr_original = calculate_snr(original_img)
            snr_processed = calculate_snr(processed_img)

            # Store metrics
            all_metrics.append({
                'filename': filename,
                'SNR_original': snr_original,
                'SNR_processed': snr_processed,
                'SNR_improvement': snr_processed - snr_original
            })

            # Create comparison plot
            create_comparison_plot(original_img, processed_img, snr_original, snr_processed, filename)

            # Add to PDF
            pdf.add_page()
            pdf.set_font('Arial', 'B', 12)
            pdf.cell(0, 10, f'Image: {filename}', ln=True)
            pdf.image(f'temp_{filename}.png', x=10, w=190)

            # Add SNR values
            pdf.set_font('Arial', '', 10)
            pdf.cell(0, 10, f'SNR Improvement: {snr_processed - snr_original:.2f} dB', ln=True)

            # Clean up temporary files
            os.remove(f'temp_{filename}.png')

            # Print progress
            print(f"Processed {filename}")

# Add summary statistics
pdf.add_page()
pdf.set_font('Arial', 'B', 14)
pdf.cell(0, 10, 'Summary Statistics', ln=True)
pdf.set_font('Arial', '', 12)

# Calculate summary statistics
avg_snr_improvement = np.mean([m['SNR_improvement'] for m in all_metrics])
max_snr_improvement = np.max([m['SNR_improvement'] for m in all_metrics])
min_snr_improvement = np.min([m['SNR_improvement'] for m in all_metrics])

# Add statistics to PDF
pdf.cell(0, 10, f'Average SNR Improvement: {avg_snr_improvement:.2f} dB', ln=True)
pdf.cell(0, 10, f'Maximum SNR Improvement: {max_snr_improvement:.2f} dB', ln=True)
pdf.cell(0, 10, f'Minimum SNR Improvement: {min_snr_improvement:.2f} dB', ln=True)

# Create SNR improvement distribution plot
plt.figure(figsize=(10, 6))
improvements = [m['SNR_improvement'] for m in all_metrics]
plt.hist(improvements, bins=30, edgecolor='black')
plt.title('Distribution of SNR Improvements')
plt.xlabel('SNR Improvement (dB)')
plt.ylabel('Number of Images')
plt.savefig('snr_distribution.png', bbox_inches='tight', dpi=300)
plt.close()

# Add distribution plot to PDF
pdf.add_page()
pdf.image('snr_distribution.png', x=10, w=190)
os.remove('snr_distribution.png')

# Save PDF
pdf_path = os.path.join(output_dir, 'thermal_image_snr_analysis.pdf')
pdf.output(pdf_path)

print(f"\nAnalysis completed. PDF report saved to: {pdf_path}")

# Print overall statistics
print(f"\nSummary Statistics:")
print(f"Average SNR Improvement: {avg_snr_improvement:.2f} dB")
print(f"Maximum SNR Improvement: {max_snr_improvement:.2f} dB")
print(f"Minimum SNR Improvement: {min_snr_improvement:.2f} dB")
# Out:
# Collecting fpdf2
#   Downloading fpdf2-2.8.2-py2.py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from fpdf2) (0.7.1)
# Requirement already satisfied: Pillow!=9.2.*,>=6.2.2 in /usr/local/lib/python3.11/dist-packages (from fpdf2) (11.1.0)
# Requirement already satisfied: fonttools>=4.34.0 in /usr/local/lib/python3.11/dist-packages (from fpdf2) (4.55.8)
# Downloading fpdf2-2.8.2-py2.py3-none-any.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 kB 9.2 MB/s eta 0:00:00
# Installing collected packages: fpdf2
# Successfully installed fpdf2-2.8.2
# <ipython-input-4-4c44c1853ed1>:63: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', 'B', 16)
# <ipython-input-4-4c44c1853ed1>:64: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, 'Thermal Image SNR Analysis Report', ln=True, align='C')
# <ipython-input-4-4c44c1853ed1>:65: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', '', 12)
# <ipython-input-4-4c44c1853ed1>:66: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, f'Generated on {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}', ln=True, align='C')
# Processing images...
# <ipython-input-4-4c44c1853ed1>:101: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', 'B', 12)
# <ipython-input-4-4c44c1853ed1>:102: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, f'Image: {filename}', ln=True)
# <ipython-input-4-4c44c1853ed1>:106: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', '', 10)
# <ipython-input-4-4c44c1853ed1>:107: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, f'SNR Improvement: {snr_processed - snr_original:.2f} dB', ln=True)
# Processed P1X1_train_norm_image_0000.png
# Processed P1X1_train_norm_image_0001.png
# Processed P1X1_train_norm_image_0002.png
# Processed P1X1_train_norm_image_0003.png
# Processed P1X1_train_norm_image_0004.png
# Processed P1X1_train_norm_image_0005.png
# Processed P1X1_train_norm_image_0006.png
# Processed P1X1_train_norm_image_0007.png
# Processed P1X1_train_norm_image_0008.png
# Processed P1X1_train_norm_image_0009.png
# Processed P1X1_train_norm_image_0010.png
# Processed P1X1_train_norm_image_0011.png
# Processed P1X1_train_norm_image_0012.png
# Processed P1X1_train_norm_image_0013.png
# Processed P1X1_train_norm_image_0014.png
# Processed P1X1_train_norm_image_0015.png
# Processed P1X1_train_norm_image_0016.png
# Processed P1X1_train_norm_image_0017.png
# Processed P1X1_train_norm_image_0018.png
# Processed P1X1_train_norm_image_0019.png
# Processed P1X1_train_norm_image_0020.png
# Processed P1X1_train_norm_image_0021.png
# Processed P1X1_train_norm_image_0022.png
# Processed P1X1_train_norm_image_0023.png
# Processed P1X1_train_norm_image_0024.png
# Processed P1X1_train_norm_image_0025.png
# Processed P1X1_train_norm_image_0026.png
# Processed P1X1_train_norm_image_0027.png
# Processed P1X1_train_norm_image_0028.png
# Processed P1X1_train_norm_image_0029.png
# Processed P1X1_train_norm_image_0030.png
# Processed P1X1_train_norm_image_0031.png
# Processed P1X1_train_norm_image_0032.png
# Processed P1X1_train_norm_image_0033.png
# Processed P1X1_train_norm_image_0034.png
# Processed P1X1_train_norm_image_0035.png
# Processed P1X1_train_norm_image_0036.png
# Processed P1X1_train_norm_image_0037.png
# Processed P1X1_train_norm_image_0038.png
# Processed P1X1_train_norm_image_0039.png
# Processed P1X1_train_norm_image_0040.png
# Processed P1X1_train_norm_image_0041.png
# Processed P1X1_train_norm_image_0042.png
# Processed P1X1_train_norm_image_0043.png
# Processed P1X1_train_norm_image_0044.png
# Processed P1X1_train_norm_image_0045.png
# Processed P1X1_train_norm_image_0046.png
# Processed P1X1_train_norm_image_0047.png
# Processed P1X1_train_norm_image_0048.png
# Processed P1X1_train_norm_image_0049.png
# Processed P1X1_train_norm_image_0050.png
# Processed P1X1_train_norm_image_0051.png
# Processed P1X1_train_norm_image_0052.png
# Processed P1X1_train_norm_image_0053.png
# Processed P1X1_train_norm_image_0054.png
# Processed P1X1_train_norm_image_0055.png
# Processed P1X1_train_norm_image_0056.png
# Processed P1X1_train_norm_image_0057.png
# Processed P1X1_train_norm_image_0058.png
# Processed P1X1_train_norm_image_0059.png
# Processed P1X1_train_norm_image_0060.png
# Processed P1X1_train_norm_image_0061.png
# Processed P1X1_train_norm_image_0062.png
# Processed P1X1_train_norm_image_0063.png
# Processed P1X1_train_norm_image_0064.png
# Processed P1X1_train_norm_image_0065.png
# Processed P1X1_train_norm_image_0066.png
# Processed P1X1_train_norm_image_0067.png
# Processed P1X1_train_norm_image_0068.png
# Processed P1X1_train_norm_image_0069.png
# Processed P1X1_train_norm_image_0070.png
# Processed P1X1_train_norm_image_0071.png
# Processed P1X1_train_norm_image_0072.png
# Processed P1X1_train_norm_image_0073.png
# Processed P1X1_train_norm_image_0074.png
# Processed P1X1_train_norm_image_0075.png
# Processed P1X1_train_norm_image_0076.png
# Processed P1X1_train_norm_image_0077.png
# Processed P1X1_train_norm_image_0078.png
# Processed P1X1_train_norm_image_0079.png
# Processed P1X1_train_norm_image_0080.png
# Processed P1X1_train_norm_image_0081.png
# Processed P1X1_train_norm_image_0082.png
# Processed P1X1_train_norm_image_0083.png
# Processed P1X1_train_norm_image_0084.png
# Processed P1X1_train_norm_image_0085.png
# Processed P1X1_train_norm_image_0086.png
# Processed P1X1_train_norm_image_0087.png
# Processed P1X1_train_norm_image_0088.png
# Processed P1X1_train_norm_image_0089.png
# Processed P1X1_train_norm_image_0090.png
# Processed P1X1_train_norm_image_0091.png
# Processed P1X1_train_norm_image_0092.png
# Processed P1X1_train_norm_image_0093.png
# Processed P1X1_train_norm_image_0094.png
# Processed P1X1_train_norm_image_0095.png
# Processed P1X1_train_norm_image_0096.png
# Processed P1X1_train_norm_image_0097.png
# Processed P1X1_train_norm_image_0098.png
# Processed P1X1_train_norm_image_0099.png
# Processed P1X1_train_norm_image_0100.png
# Processed P1X1_train_norm_image_0101.png
# Processed P1X1_train_norm_image_0102.png
# Processed P1X1_train_norm_image_0103.png
# Processed P1X1_train_norm_image_0104.png
# Processed P1X1_train_norm_image_0105.png
# Processed P1X1_train_norm_image_0106.png
# Processed P1X1_train_norm_image_0107.png
# Processed P1X1_train_norm_image_0108.png
# Processed P1X1_train_norm_image_0109.png
# Processed P1X1_train_norm_image_0110.png
# Processed P1X1_train_norm_image_0111.png
# Processed P1X1_train_norm_image_0112.png
# Processed P1X1_train_norm_image_0113.png
# Processed P1X1_train_norm_image_0114.png
# Processed P1X1_train_norm_image_0115.png
# Processed P1X1_train_norm_image_0116.png
# Processed P1X1_train_norm_image_0117.png
# Processed P1X1_train_norm_image_0118.png
# Processed P1X1_train_norm_image_0119.png
# Processed P1X2_train_norm_image_0000.png
# Processed P1X2_train_norm_image_0001.png
# Processed P1X2_train_norm_image_0002.png
# Processed P1X2_train_norm_image_0003.png
# Processed P1X2_train_norm_image_0004.png
# Processed P1X2_train_norm_image_0005.png
# Processed P1X2_train_norm_image_0006.png
# Processed P1X2_train_norm_image_0007.png
# Processed P1X2_train_norm_image_0008.png
# Processed P1X2_train_norm_image_0009.png
# Processed P1X2_train_norm_image_0010.png
# Processed P1X2_train_norm_image_0011.png
# Processed P1X2_train_norm_image_0012.png
# Processed P1X2_train_norm_image_0013.png
# Processed P1X2_train_norm_image_0014.png
# Processed P1X2_train_norm_image_0015.png
# Processed P1X2_train_norm_image_0016.png
# Processed P1X2_train_norm_image_0017.png
# Processed P1X2_train_norm_image_0018.png
# Processed P1X2_train_norm_image_0019.png
# Processed P1X2_train_norm_image_0020.png
# Processed P1X2_train_norm_image_0021.png
# Processed P1X2_train_norm_image_0022.png
# Processed P1X2_train_norm_image_0023.png
# Processed P1X2_train_norm_image_0024.png
# Processed P1X2_train_norm_image_0025.png
# Processed P1X2_train_norm_image_0026.png
# Processed P1X2_train_norm_image_0027.png
# Processed P1X2_train_norm_image_0028.png
# Processed P1X2_train_norm_image_0029.png
# Processed P1X2_train_norm_image_0030.png
# Processed P1X2_train_norm_image_0031.png
# Processed P1X2_train_norm_image_0032.png
# Processed P1X2_train_norm_image_0033.png
# Processed P1X2_train_norm_image_0034.png
# Processed P1X2_train_norm_image_0035.png
# Processed P1X2_train_norm_image_0036.png
# Processed P1X2_train_norm_image_0037.png
# Processed P1X2_train_norm_image_0038.png
# Processed P1X2_train_norm_image_0039.png
# Processed P1X2_train_norm_image_0040.png
# Processed P1X2_train_norm_image_0041.png
# Processed P1X2_train_norm_image_0042.png
# Processed P1X2_train_norm_image_0043.png
# Processed P1X2_train_norm_image_0044.png
# Processed P1X2_train_norm_image_0045.png
# Processed P1X2_train_norm_image_0046.png
# Processed P1X2_train_norm_image_0047.png
# Processed P1X2_train_norm_image_0048.png
# Processed P1X2_train_norm_image_0049.png
# Processed P1X2_train_norm_image_0050.png
# Processed P1X2_train_norm_image_0051.png
# Processed P1X2_train_norm_image_0052.png
# Processed P1X2_train_norm_image_0053.png
# Processed P1X2_train_norm_image_0054.png
# Processed P1X2_train_norm_image_0055.png
# Processed P1X2_train_norm_image_0056.png
# Processed P1X2_train_norm_image_0057.png
# Processed P1X2_train_norm_image_0058.png
# Processed P1X2_train_norm_image_0059.png
# Processed P1X2_train_norm_image_0060.png
# Processed P1X2_train_norm_image_0061.png
# Processed P1X2_train_norm_image_0062.png
# Processed P1X2_train_norm_image_0063.png
# Processed P1X2_train_norm_image_0064.png
# Processed P1X2_train_norm_image_0065.png
# Processed P1X2_train_norm_image_0066.png
# Processed P1X2_train_norm_image_0067.png
# Processed P1X2_train_norm_image_0068.png
# Processed P1X2_train_norm_image_0069.png
# Processed P1X2_train_norm_image_0070.png
# Processed P1X2_train_norm_image_0071.png
# Processed P1X2_train_norm_image_0072.png
# Processed P1X2_train_norm_image_0073.png
# Processed P1X2_train_norm_image_0074.png
# Processed P1X2_train_norm_image_0075.png
# Processed P1X2_train_norm_image_0076.png
# Processed P1X2_train_norm_image_0077.png
# Processed P1X2_train_norm_image_0078.png
# Processed P1X2_train_norm_image_0079.png
# Processed P1X2_train_norm_image_0080.png
# Processed P1X2_train_norm_image_0081.png
# Processed P1X2_train_norm_image_0082.png
# Processed P1X2_train_norm_image_0083.png
# Processed P1X2_train_norm_image_0084.png
# Processed P1X2_train_norm_image_0085.png
# Processed P1X2_train_norm_image_0086.png
# Processed P1X2_train_norm_image_0087.png
# Processed P1X2_train_norm_image_0088.png
# Processed P1X2_train_norm_image_0089.png
# Processed P1X2_train_norm_image_0090.png
# Processed P1X2_train_norm_image_0091.png
# Processed P1X2_train_norm_image_0092.png
# Processed P1X2_train_norm_image_0093.png
# Processed P1X2_train_norm_image_0094.png
# Processed P1X2_train_norm_image_0095.png
# Processed P1X2_train_norm_image_0096.png
# Processed P1X2_train_norm_image_0097.png
# Processed P1X2_train_norm_image_0098.png
# Processed P1X2_train_norm_image_0099.png
# Processed P1X2_train_norm_image_0100.png
# Processed P1X2_train_norm_image_0101.png
# Processed P1X2_train_norm_image_0102.png
# Processed P1X2_train_norm_image_0103.png
# Processed P1X2_train_norm_image_0104.png
# Processed P1X2_train_norm_image_0105.png
# Processed P1X2_train_norm_image_0106.png
# Processed P1X2_train_norm_image_0107.png
# Processed P1X2_train_norm_image_0108.png
# Processed P1X2_train_norm_image_0109.png
# Processed P1X2_train_norm_image_0110.png
# Processed P1X2_train_norm_image_0111.png
# Processed P1X2_train_norm_image_0112.png
# Processed P1X2_train_norm_image_0113.png
# Processed P1X2_train_norm_image_0114.png
# Processed P1X2_train_norm_image_0115.png
# Processed P1X2_train_norm_image_0116.png
# Processed P1X2_train_norm_image_0117.png
# Processed P1X2_train_norm_image_0118.png
# Processed P1X2_train_norm_image_0119.png
# Processed P2X1_train_norm_image_0000.png
# Processed P2X1_train_norm_image_0001.png
# Processed P2X1_train_norm_image_0002.png
# Processed P2X1_train_norm_image_0003.png
# Processed P2X1_train_norm_image_0004.png
# Processed P2X1_train_norm_image_0005.png
# Processed P2X1_train_norm_image_0006.png
# Processed P2X1_train_norm_image_0007.png
# Processed P2X1_train_norm_image_0008.png
# Processed P2X1_train_norm_image_0009.png
# Processed P2X1_train_norm_image_0010.png
# Processed P2X1_train_norm_image_0011.png
# Processed P2X1_train_norm_image_0012.png
# Processed P2X1_train_norm_image_0013.png
# Processed P2X1_train_norm_image_0014.png
# Processed P2X1_train_norm_image_0015.png
# Processed P2X1_train_norm_image_0016.png
# Processed P2X1_train_norm_image_0017.png
# Processed P2X1_train_norm_image_0018.png
# Processed P2X1_train_norm_image_0019.png
# Processed P2X1_train_norm_image_0020.png
# Processed P2X1_train_norm_image_0021.png
# Processed P2X1_train_norm_image_0022.png
# Processed P2X1_train_norm_image_0023.png
# Processed P2X1_train_norm_image_0024.png
# Processed P2X1_train_norm_image_0025.png
# Processed P2X1_train_norm_image_0026.png
# Processed P2X1_train_norm_image_0027.png
# Processed P2X1_train_norm_image_0028.png
# Processed P2X1_train_norm_image_0029.png
# Processed P2X1_train_norm_image_0030.png
# Processed P2X1_train_norm_image_0031.png
# Processed P2X1_train_norm_image_0032.png
# Processed P2X1_train_norm_image_0033.png
# Processed P2X1_train_norm_image_0034.png
# Processed P2X1_train_norm_image_0035.png
# Processed P2X1_train_norm_image_0036.png
# Processed P2X1_train_norm_image_0037.png
# Processed P2X1_train_norm_image_0038.png
# Processed P2X1_train_norm_image_0039.png
# Processed P2X1_train_norm_image_0040.png
# Processed P2X1_train_norm_image_0041.png
# Processed P2X1_train_norm_image_0042.png
# Processed P2X1_train_norm_image_0043.png
# Processed P2X1_train_norm_image_0044.png
# Processed P2X1_train_norm_image_0045.png
# Processed P2X1_train_norm_image_0046.png
# Processed P2X1_train_norm_image_0047.png
# Processed P2X1_train_norm_image_0048.png
# Processed P2X1_train_norm_image_0049.png
# Processed P2X1_train_norm_image_0050.png
# Processed P2X1_train_norm_image_0051.png
# Processed P2X1_train_norm_image_0052.png
# Processed P2X1_train_norm_image_0053.png
# Processed P2X1_train_norm_image_0054.png
# Processed P2X1_train_norm_image_0055.png
# Processed P2X1_train_norm_image_0056.png
# Processed P2X1_train_norm_image_0057.png
# Processed P2X1_train_norm_image_0058.png
# Processed P2X1_train_norm_image_0059.png
# Processed P2X1_train_norm_image_0060.png
# Processed P2X1_train_norm_image_0061.png
# Processed P2X1_train_norm_image_0062.png
# Processed P2X1_train_norm_image_0063.png
# Processed P2X1_train_norm_image_0064.png
# Processed P2X1_train_norm_image_0065.png
# Processed P2X1_train_norm_image_0066.png
# Processed P2X1_train_norm_image_0067.png
# Processed P2X1_train_norm_image_0068.png
# Processed P2X1_train_norm_image_0069.png
# Processed P2X1_train_norm_image_0070.png
# Processed P2X1_train_norm_image_0071.png
# Processed P2X1_train_norm_image_0072.png
# Processed P2X1_train_norm_image_0073.png
# Processed P2X1_train_norm_image_0074.png
# Processed P2X1_train_norm_image_0075.png
# Processed P2X1_train_norm_image_0076.png
# Processed P2X1_train_norm_image_0077.png
# Processed P2X1_train_norm_image_0078.png
# Processed P2X1_train_norm_image_0079.png
# Processed P2X1_train_norm_image_0080.png
# Processed P2X1_train_norm_image_0081.png
# Processed P2X1_train_norm_image_0082.png
# Processed P2X1_train_norm_image_0083.png
# Processed P2X1_train_norm_image_0084.png
# Processed P2X1_train_norm_image_0085.png
# Processed P2X1_train_norm_image_0086.png
# Processed P2X1_train_norm_image_0087.png
# Processed P2X1_train_norm_image_0088.png
# Processed P2X1_train_norm_image_0089.png
# Processed P2X1_train_norm_image_0090.png
# Processed P2X1_train_norm_image_0091.png
# Processed P2X1_train_norm_image_0092.png
# Processed P2X1_train_norm_image_0093.png
# Processed P2X1_train_norm_image_0094.png
# Processed P2X1_train_norm_image_0095.png
# Processed P2X1_train_norm_image_0096.png
# Processed P2X1_train_norm_image_0097.png
# Processed P2X1_train_norm_image_0098.png
# Processed P2X1_train_norm_image_0099.png
# Processed P2X1_train_norm_image_0100.png
# Processed P2X1_train_norm_image_0101.png
# Processed P2X1_train_norm_image_0102.png
# Processed P2X1_train_norm_image_0103.png
# Processed P2X1_train_norm_image_0104.png
# Processed P2X1_train_norm_image_0105.png
# Processed P2X1_train_norm_image_0106.png
# Processed P2X1_train_norm_image_0107.png
# Processed P2X1_train_norm_image_0108.png
# Processed P2X1_train_norm_image_0109.png
# Processed P2X1_train_norm_image_0110.png
# Processed P2X1_train_norm_image_0111.png
# Processed P2X1_train_norm_image_0112.png
# Processed P2X1_train_norm_image_0113.png
# Processed P2X1_train_norm_image_0114.png
# Processed P2X1_train_norm_image_0115.png
# Processed P2X1_train_norm_image_0116.png
# Processed P2X1_train_norm_image_0117.png
# Processed P2X1_train_norm_image_0118.png
# Processed P2X1_train_norm_image_0119.png
# Processed P2X2_train_norm_image_0000.png
# Processed P2X2_train_norm_image_0001.png
# Processed P2X2_train_norm_image_0002.png
# Processed P2X2_train_norm_image_0003.png
# Processed P2X2_train_norm_image_0004.png
# Processed P2X2_train_norm_image_0005.png
# Processed P2X2_train_norm_image_0006.png
# Processed P2X2_train_norm_image_0007.png
# Processed P2X2_train_norm_image_0008.png
# Processed P2X2_train_norm_image_0009.png
# Processed P2X2_train_norm_image_0010.png
# Processed P2X2_train_norm_image_0011.png
# Processed P2X2_train_norm_image_0012.png
# Processed P2X2_train_norm_image_0013.png
# Processed P2X2_train_norm_image_0014.png
# Processed P2X2_train_norm_image_0015.png
# Processed P2X2_train_norm_image_0016.png
# Processed P2X2_train_norm_image_0017.png
# Processed P2X2_train_norm_image_0018.png
# Processed P2X2_train_norm_image_0019.png
# Processed P2X2_train_norm_image_0020.png
# Processed P2X2_train_norm_image_0021.png
# Processed P2X2_train_norm_image_0022.png
# Processed P2X2_train_norm_image_0023.png
# Processed P2X2_train_norm_image_0024.png
# Processed P2X2_train_norm_image_0025.png
# Processed P2X2_train_norm_image_0026.png
# Processed P2X2_train_norm_image_0027.png
# Processed P2X2_train_norm_image_0028.png
# Processed P2X2_train_norm_image_0029.png
# Processed P2X2_train_norm_image_0030.png
# Processed P2X2_train_norm_image_0031.png
# Processed P2X2_train_norm_image_0032.png
# Processed P2X2_train_norm_image_0033.png
# Processed P2X2_train_norm_image_0034.png
# Processed P2X2_train_norm_image_0035.png
# Processed P2X2_train_norm_image_0036.png
# Processed P2X2_train_norm_image_0037.png
# Processed P2X2_train_norm_image_0038.png
# Processed P2X2_train_norm_image_0039.png
# Processed P2X2_train_norm_image_0040.png
# Processed P2X2_train_norm_image_0041.png
# Processed P2X2_train_norm_image_0042.png
# Processed P2X2_train_norm_image_0043.png
# Processed P2X2_train_norm_image_0044.png
# Processed P2X2_train_norm_image_0045.png
# Processed P2X2_train_norm_image_0046.png
# Processed P2X2_train_norm_image_0047.png
# Processed P2X2_train_norm_image_0048.png
# Processed P2X2_train_norm_image_0049.png
# Processed P2X2_train_norm_image_0050.png
# Processed P2X2_train_norm_image_0051.png
# Processed P2X2_train_norm_image_0052.png
# Processed P2X2_train_norm_image_0053.png
# Processed P2X2_train_norm_image_0054.png
# Processed P2X2_train_norm_image_0055.png
# Processed P2X2_train_norm_image_0056.png
# Processed P2X2_train_norm_image_0057.png
# Processed P2X2_train_norm_image_0058.png
# Processed P2X2_train_norm_image_0059.png
# Processed P2X2_train_norm_image_0060.png
# Processed P2X2_train_norm_image_0061.png
# Processed P2X2_train_norm_image_0062.png
# Processed P2X2_train_norm_image_0063.png
# Processed P2X2_train_norm_image_0064.png
# Processed P2X2_train_norm_image_0065.png
# Processed P2X2_train_norm_image_0066.png
# Processed P2X2_train_norm_image_0067.png
# Processed P2X2_train_norm_image_0068.png
# Processed P2X2_train_norm_image_0069.png
# Processed P2X2_train_norm_image_0070.png
# Processed P2X2_train_norm_image_0071.png
# Processed P2X2_train_norm_image_0072.png
# Processed P2X2_train_norm_image_0073.png
# Processed P2X2_train_norm_image_0074.png
# Processed P2X2_train_norm_image_0075.png
# Processed P2X2_train_norm_image_0076.png
# Processed P2X2_train_norm_image_0077.png
# Processed P2X2_train_norm_image_0078.png
# Processed P2X2_train_norm_image_0079.png
# Processed P2X2_train_norm_image_0080.png
# Processed P2X2_train_norm_image_0081.png
# Processed P2X2_train_norm_image_0082.png
# Processed P2X2_train_norm_image_0083.png
# Processed P2X2_train_norm_image_0084.png
# Processed P2X2_train_norm_image_0085.png
# Processed P2X2_train_norm_image_0086.png
# Processed P2X2_train_norm_image_0087.png
# Processed P2X2_train_norm_image_0088.png
# Processed P2X2_train_norm_image_0089.png
# Processed P2X2_train_norm_image_0090.png
# Processed P2X2_train_norm_image_0091.png
# Processed P2X2_train_norm_image_0092.png
# Processed P2X2_train_norm_image_0093.png
# Processed P2X2_train_norm_image_0094.png
# Processed P2X2_train_norm_image_0095.png
# Processed P2X2_train_norm_image_0096.png
# Processed P2X2_train_norm_image_0097.png
# Processed P2X2_train_norm_image_0098.png
# Processed P2X2_train_norm_image_0099.png
# Processed P2X2_train_norm_image_0100.png
# Processed P2X2_train_norm_image_0101.png
# Processed P2X2_train_norm_image_0102.png
# Processed P2X2_train_norm_image_0103.png
# Processed P2X2_train_norm_image_0104.png
# Processed P2X2_train_norm_image_0105.png
# Processed P2X2_train_norm_image_0106.png
# Processed P2X2_train_norm_image_0107.png
# Processed P2X2_train_norm_image_0108.png
# Processed P2X2_train_norm_image_0109.png
# Processed P2X2_train_norm_image_0110.png
# Processed P2X2_train_norm_image_0111.png
# Processed P2X2_train_norm_image_0112.png
# Processed P2X2_train_norm_image_0113.png
# Processed P2X2_train_norm_image_0114.png
# Processed P2X2_train_norm_image_0115.png
# Processed P2X2_train_norm_image_0116.png
# Processed P2X2_train_norm_image_0117.png
# Processed P2X2_train_norm_image_0118.png
# Processed P2X2_train_norm_image_0119.png
# <ipython-input-4-4c44c1853ed1>:117: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', 'B', 14)
# <ipython-input-4-4c44c1853ed1>:118: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, 'Summary Statistics', ln=True)
# <ipython-input-4-4c44c1853ed1>:119: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial', '', 12)
# <ipython-input-4-4c44c1853ed1>:127: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, f'Average SNR Improvement: {avg_snr_improvement:.2f} dB', ln=True)
# <ipython-input-4-4c44c1853ed1>:128: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, f'Maximum SNR Improvement: {max_snr_improvement:.2f} dB', ln=True)
# <ipython-input-4-4c44c1853ed1>:129: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, f'Minimum SNR Improvement: {min_snr_improvement:.2f} dB', ln=True)
# Analysis completed. PDF report saved to: /content/drive/My Drive/Colab Notebooks/analysis_results/thermal_image_snr_analysis.pdf
#
# Summary Statistics:
# Average SNR Improvement: 1.67 dB
# Maximum SNR Improvement: 7.12 dB
# Minimum SNR Improvement: -21.62 dB

# %%
#------------------------ Training and Testing -----------------------------

# %%
# 1. Clone YOLOv5
# !git clone https://github.com/ultralytics/yolov5

# 2. Change directory to yolov5
# %cd yolov5

# 3. Install requirements
# !pip install -r requirements.txt

# 4. Start training
# !python train.py \
--img 640 \
--batch 8 \
--epochs 50 \
--patience 10 \
--data "/content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/data.yaml" \
--weights yolov5m.pt \
--cache
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (3.1.44)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (4.11.0.86)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (1.13.1)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (2.5.1+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 16)) (0.20.1+cu124)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: ultralytics>=8.2.34 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 18)) (8.3.75)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 27)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 42)) (75.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->-r requirements.txt (line 12)) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.14)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2025.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (3.0.2)
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-02-14 18:19:00.094643: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739557140.115288   26208 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739557140.121843   26208 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Currently logged in as: niranjan-sh18 (niranjan-sh18-northumbria-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# train: weights=yolov5m.pt, cfg=, data=/content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data/hyps, resume_evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=10, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Tracking run with wandb version 0.19.6
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20250214_181902-379hytxf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run blissful-hug-7
# wandb: ⭐️ View project at https://wandb.ai/niranjan-sh18-northumbria-university/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/niranjan-sh18-northumbria-university/YOLOv5/runs/379hytxf
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m.pt to yolov5m.pt...
# 100% 40.8M/40.8M [00:00<00:00, 115MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      5280  models.common.Conv                      [3, 48, 6, 2, 2]
#   1                -1  1     41664  models.common.Conv                      [48, 96, 3, 2]
#   2                -1  2     65280  models.common.C3                        [96, 96, 2]
#   3                -1  1    166272  models.common.Conv                      [96, 192, 3, 2]
#   4                -1  4    444672  models.common.C3                        [192, 192, 4]
#   5                -1  1    664320  models.common.Conv                      [192, 384, 3, 2]
#   6                -1  6   2512896  models.common.C3                        [384, 384, 6]
#   7                -1  1   2655744  models.common.Conv                      [384, 768, 3, 2]
#   8                -1  2   4134912  models.common.C3                        [768, 768, 2]
#   9                -1  1   1476864  models.common.SPPF                      [768, 768, 5]
#  10                -1  1    295680  models.common.Conv                      [768, 384, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  2   1182720  models.common.C3                        [768, 384, 2, False]
#  14                -1  1     74112  models.common.Conv                      [384, 192, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  2    296448  models.common.C3                        [384, 192, 2, False]
#  18                -1  1    332160  models.common.Conv                      [192, 192, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  2   1035264  models.common.C3                        [384, 384, 2, False]
#  21                -1  1   1327872  models.common.Conv                      [384, 384, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  2   4134912  models.common.C3                        [768, 768, 2, False]
#  24      [17, 20, 23]  1     24246  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [192, 384, 768]]
# Model summary: 291 layers, 20871318 parameters, 20871318 gradients, 48.2 GFLOPs
#
# Transferred 475/481 items from yolov5m.pt
# /content/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# /content/yolov5/models/common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 79 weight(decay=0.0), 82 weight(decay=0.0005), 82 bias
# albumentations: 6 validation errors for InitSchema
# p
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# scale
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# ratio
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# size
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# interpolation
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# mask_interpolation
#   Field required [type=missing, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# train: Scanning /content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/train/labels.cache... 336 images, 5 backgrounds, 0 corrupt: 100% 336/336 [00:00<?, ?it/s]
# train: WARNING ⚠️ /content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/train/images/grad_P2X1_train_norm_image_0038_png.rf.92e7dd371a616453e3c4d26144980182.jpg: 1 duplicate labels removed
# train: Caching images (0.4GB ram): 100% 336/336 [00:01<00:00, 174.80it/s]
# val: Scanning /content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/valid/labels.cache... 96 images, 0 backgrounds, 0 corrupt: 100% 96/96 [00:00<?, ?it/s]
# val: Caching images (0.1GB ram): 100% 96/96 [00:00<00:00, 154.06it/s]
#
# AutoAnchor: 6.07 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# /content/yolov5/train.py:355: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=amp)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#   0% 0/42 [00:00<?, ?it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.08G     0.1185    0.05625          0         66        640:   2% 1/42 [00:04<02:56,  4.30s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1179    0.04747          0         34        640:   5% 2/42 [00:04<01:20,  2.01s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1169    0.05049          0         64        640:   7% 3/42 [00:05<00:50,  1.29s/it]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1167    0.05104          0         60        640:  10% 4/42 [00:05<00:34,  1.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1163    0.05081          0         53        640:  12% 5/42 [00:05<00:24,  1.52it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1158    0.05138          0         54        640:  14% 6/42 [00:06<00:19,  1.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1155    0.05112          0         49        640:  17% 7/42 [00:06<00:15,  2.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1156    0.05111          0         55        640:  19% 8/42 [00:06<00:12,  2.62it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1151     0.0504          0         43        640:  21% 9/42 [00:06<00:10,  3.00it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49      3.09G     0.1144     0.0495          0         32        640:  24% 10/42 [00:06<00:09,  3.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1139    0.04945          0         44        640:  26% 11/42 [00:07<00:08,  3.45it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1135    0.04988          0         51        640:  29% 12/42 [00:07<00:07,  3.80it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1133    0.05056          0         61        640:  31% 13/42 [00:07<00:07,  3.91it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1128      0.051          0         53        640:  33% 14/42 [00:07<00:06,  4.11it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1123    0.05178          0         55        640:  36% 15/42 [00:08<00:06,  4.19it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1118    0.05223          0         53        640:  38% 16/42 [00:08<00:05,  4.41it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1115    0.05337          0         73        640:  40% 17/42 [00:08<00:05,  4.38it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G      0.111    0.05386          0         54        640:  43% 18/42 [00:08<00:05,  4.54it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1104    0.05367          0         40        640:  45% 19/42 [00:08<00:05,  4.46it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1097    0.05403          0         48        640:  48% 20/42 [00:09<00:04,  4.62it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1091    0.05432          0         48        640:  50% 21/42 [00:09<00:04,  4.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1085     0.0544          0         44        640:  52% 22/42 [00:09<00:04,  4.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1083    0.05576          0         84        640:  55% 23/42 [00:09<00:04,  4.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1078     0.0562          0         56        640:  57% 24/42 [00:10<00:03,  4.71it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1074    0.05626          0         49        640:  60% 25/42 [00:10<00:03,  4.61it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G      0.107    0.05659          0         55        640:  62% 26/42 [00:10<00:03,  4.67it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1067    0.05671          0         54        640:  64% 27/42 [00:10<00:03,  4.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G      0.106    0.05663          0         37        640:  67% 28/42 [00:10<00:03,  4.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1055    0.05672          0         47        640:  69% 29/42 [00:11<00:02,  4.66it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1G     0.1049    0.05664          0         41        640:  71% 30/42 [00:11<00:02,  4.57it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#        0/49       3.1
08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01972    0.02023          0         34        640:  33% 14/42 [00:03<00:06,  4.17it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01958    0.02009          0         45        640:  36% 15/42 [00:03<00:06,  4.10it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01951    0.02004          0         46        640:  38% 16/42 [00:03<00:06,  4.30it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01955    0.02004          0         51        640:  40% 17/42 [00:04<00:05,  4.38it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G     0.0195    0.02032          0         69        640:  43% 18/42 [00:04<00:05,  4.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G     0.0195    0.02038          0         54        640:  45% 19/42 [00:04<00:05,  4.50it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01945     0.0207          0         63        640:  48% 20/42 [00:04<00:04,  4.55it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01952     0.0208          0         54        640:  50% 21/42 [00:05<00:04,  4.58it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01955    0.02102          0         54        640:  52% 22/42 [00:05<00:04,  4.39it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01968    0.02098          0         40        640:  55% 23/42 [00:05<00:04,  4.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01961    0.02093          0         50        640:  57% 24/42 [00:05<00:04,  4.36it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01949    0.02105          0         64        640:  60% 25/42 [00:05<00:03,  4.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01939    0.02111          0         62        640:  62% 26/42 [00:06<00:03,  4.43it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01953     0.0211          0         34        640:  64% 27/42 [00:06<00:03,  4.49it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01962    0.02149          0         73        640:  67% 28/42 [00:06<00:03,  4.44it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01956    0.02161          0         62        640:  69% 29/42 [00:06<00:03,  4.22it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01959    0.02152          0         46        640:  71% 30/42 [00:07<00:02,  4.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01948    0.02155          0         58        640:  74% 31/42 [00:07<00:02,  4.04it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01945    0.02158          0         52        640:  76% 32/42 [00:07<00:02,  4.06it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G     0.0195    0.02157          0         48        640:  79% 33/42 [00:07<00:02,  4.15it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01953     0.0215          0         41        640:  81% 34/42 [00:08<00:01,  4.27it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01956    0.02138          0         36        640:  83% 35/42 [00:08<00:01,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01961    0.02141          0         37        640:  86% 36/42 [00:08<00:01,  4.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01962    0.02165          0         85        640:  88% 37/42 [00:08<00:01,  4.22it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01963    0.02165          0         50        640:  90% 38/42 [00:09<00:00,  4.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01969    0.02173          0         45        640:  93% 39/42 [00:09<00:00,  4.21it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01968    0.02187          0         65        640:  95% 40/42 [00:09<00:00,  4.28it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01963    0.02161          0         31        640:  98% 41/42 [00:09<00:00,  4.34it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       49/49      3.72G    0.01971    0.02173          0         53        640: 100% 42/42 [00:09<00:00,  4.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 6/6 [00:01<00:00,  3.93it/s]
#                    all         96        433      0.963      0.957      0.983      0.744
#
# 50 epochs completed in 0.183 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 42.2MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 42.2MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 6/6 [00:04<00:00,  1.40it/s]
#                    all         96        433      0.971      0.949      0.984      0.747
# Results saved to runs/train/exp
# wandb: ⢿ uploading artifact run_379hytxf_model (1.3s)
# wandb:   ↳ ⢿ best.pt 29.1MB/40.3MB (1.0s)
# wandb: ⣻ uploading artifact run_379hytxf_model (1.3s)
# wandb:   ↳ ⣻ best.pt 29.1MB/40.3MB (1.0s)
# wandb:
# wandb: ⣻ uploading artifact run_379hytxf_model (1.3s)
# wandb:   ↳ ⣻ best.pt 29.1MB/40.3MB (1.0s)
# wandb:
# wandb: Run history:
# wandb:      metrics/mAP_0.5 ▃▁▃▅▆▆▇▇▇██▇▇█████████████████▇█████████
# wandb: metrics/mAP_0.5:0.95 ▂▁▂▃▄▅▆▅▆▅▅▇▆▆▇▇▇▇▇▇▇▇▇▇█▇██▇███████████
# wandb:    metrics/precision ▁▁▅▄▃▅▆▆▇▇▇▇▇▇▇█▇▇▇█▇▇▇████▇█▇██████████
# wandb:       metrics/recall ▁▂▂▂▄▆▆▄▆▇▇▆▆▇▇█████▆▇█▇██▇████▆████████
# wandb:       train/box_loss █▆▆▆▅▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       train/cls_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       train/obj_loss █▇▅▅▄▄▃▃▃▃▃▃▃▂▃▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:         val/box_loss ██▇▅▅▄▄▃▃▄▂▃▂▂▂▂▂▂▂▂▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         val/cls_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         val/obj_loss █▆▄▄▄▃▃▃▄▂▂▃▄▂▂▂▂▂▂▂▂▁▂▁▂▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                x/lr0 █▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                x/lr1 ▃▆███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                x/lr2 ▃▆███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁
# wandb:
# wandb: Run summary:
# wandb:           best/epoch 48
# wandb:         best/mAP_0.5 0.98365
# wandb:    best/mAP_0.5:0.95 0.74672
# wandb:       best/precision 0.97139
# wandb:          best/recall 0.94919
# wandb:      metrics/mAP_0.5 0.98366
# wandb: metrics/mAP_0.5:0.95 0.74683
# wandb:    metrics/precision 0.97071
# wandb:       metrics/recall 0.94919
# wandb:       train/box_loss 0.01971
# wandb:       train/cls_loss 0
# wandb:       train/obj_loss 0.02173
# wandb:         val/box_loss 0.02127
# wandb:         val/cls_loss 0
# wandb:         val/obj_loss 0.0149
# wandb:                x/lr0 0.0005
# wandb:                x/lr1 0.0005
# wandb:                x/lr2 0.0005
# wandb:
# wandb: 🚀 View run blissful-hug-7 at: https://wandb.ai/niranjan-sh18-northumbria-university/YOLOv5/runs/379hytxf
# wandb: ⭐️ View project at: https://wandb.ai/niranjan-sh18-northumbria-university/YOLOv5
# wandb: Synced 5 W&B file(s), 17 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250214_181902-379hytxf/logs
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.

# %%
# YOLOv5 directory
# %cd /content/yolov5

# Run testing on test dataset
# !python val.py \
  --weights runs/train/exp/weights/best.pt \
  --data "/content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/data.yaml" \
  --img 640 \
  --task test
# Out:
# /content/yolov5
# val: data=/content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-398-g5cdad892 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# test: Scanning /content/drive/My Drive/Colab Notebooks/CFRP Defect Detection.v1i.yolov5pytorch/test/labels.cache... 48 images, 2 backgrounds, 0 corrupt: 100% 48/48 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.29s/it]
#                    all         48        216      0.932      0.958      0.955      0.761
# Speed: 0.2ms pre-process, 23.7ms inference, 7.0ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val/exp3

# %%
# !zip -r yolov5.zip /content/yolov5
# Out:
#   adding: content/yolov5/ (stored 0%)
#   adding: content/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/.gitignore (deflated 55%)
#   adding: content/yolov5/pyproject.toml (deflated 59%)
#   adding: content/yolov5/__pycache__/ (stored 0%)
#   adding: content/yolov5/__pycache__/hubconf.cpython-311.pyc (deflated 74%)
#   adding: content/yolov5/__pycache__/export.cpython-311.pyc (deflated 60%)
#   adding: content/yolov5/__pycache__/val.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/README.zh-CN.md (deflated 76%)
#   adding: content/yolov5/yolov5/ (stored 0%)
#   adding: content/yolov5/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/yolov5/.gitignore (deflated 55%)
#   adding: content/yolov5/yolov5/pyproject.toml (deflated 59%)
#   adding: content/yolov5/yolov5/__pycache__/ (stored 0%)
#   adding: content/yolov5/yolov5/__pycache__/val.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/yolov5/README.zh-CN.md (deflated 76%)
#   adding: content/yolov5/yolov5/yolov5/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/.gitignore (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/pyproject.toml (deflated 59%)
#   adding: content/yolov5/yolov5/yolov5/__pycache__/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/__pycache__/val.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/README.zh-CN.md (deflated 76%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.gitignore (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/pyproject.toml (deflated 59%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/__pycache__/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/__pycache__/val.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/README.zh-CN.md (deflated 76%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.dockerignore (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.gitignore (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/pyproject.toml (deflated 59%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/__pycache__/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/__pycache__/val.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/README.zh-CN.md (deflated 76%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/dependabot.yml (deflated 54%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/docker.yml (deflated 67%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/links.yml (deflated 63%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/stale.yml (deflated 58%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/merge-main-into-prs.yml (deflated 66%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/format.yml (deflated 61%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/cla.yml (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/workflows/ci-testing.yml (deflated 71%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/bug-report.yml (deflated 60%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/config.yml (deflated 49%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/feature-request.yml (deflated 61%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/question.yml (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/yolov5m.pt (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/hubconf.py (deflated 82%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/export.py (deflated 73%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/.gitattributes (deflated 4%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/CONTRIBUTING.md (deflated 57%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 45%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/events.out.tfevents.1739555268.b2ae729ab4dd.18101.0 (deflated 47%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 13%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/R_curve.png (deflated 17%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/results.csv (deflated 84%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 14%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 7%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/train_batch0.jpg (deflated 5%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/PR_curve.png (deflated 27%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/F1_curve.png (deflated 16%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/P_curve.png (deflated 20%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/labels.jpg (deflated 44%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/train_batch2.jpg (deflated 5%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 7%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/weights/last.pt (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/runs/train/exp/weights/best.pt (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5
)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/loggers/comet/README.md (deflated 64%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/loggers/comet/comet_utils.py (deflated 69%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/loggers/comet/hpo.py (deflated 67%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/plots.py (deflated 64%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/autobatch.py (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/__init__.cpython-311.pyc (deflated 47%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/autobatch.cpython-311.pyc (deflated 46%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/general.cpython-311.pyc (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/augmentations.cpython-311.pyc (deflated 54%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/plots.cpython-311.pyc (deflated 53%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/metrics.cpython-311.pyc (deflated 53%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/autoanchor.cpython-311.pyc (deflated 50%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/dataloaders.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/torch_utils.cpython-311.pyc (deflated 53%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/loss.cpython-311.pyc (deflated 54%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/downloads.cpython-311.pyc (deflated 50%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__pycache__/callbacks.cpython-311.pyc (deflated 52%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/downloads.py (deflated 62%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/callbacks.py (deflated 68%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/general.py (deflated 66%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/augmentations.py (deflated 66%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/torch_utils.py (deflated 64%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/flask_rest_api/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/flask_rest_api/example_request.py (deflated 29%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/flask_rest_api/restapi.py (deflated 49%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/flask_rest_api/README.md (deflated 52%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/activations.py (deflated 70%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/google_app_engine/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/google_app_engine/additional_requirements.txt (deflated 41%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/google_app_engine/Dockerfile (deflated 47%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/google_app_engine/app.yaml (deflated 22%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/docker/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/docker/Dockerfile-arm64 (deflated 51%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/docker/Dockerfile-cpu (deflated 51%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/docker/Dockerfile (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/dataloaders.py (deflated 70%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/loss.py (deflated 66%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/plots.py (deflated 63%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/general.py (deflated 70%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/augmentations.py (deflated 62%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/dataloaders.py (deflated 70%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/__init__.py (deflated 14%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/segment/metrics.py (deflated 73%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/__init__.py (deflated 57%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/aws/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/aws/__init__.py (deflated 14%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/aws/userdata.sh (deflated 47%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/aws/mime.sh (deflated 46%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/aws/resume.py (deflated 45%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/metrics.py (deflated 66%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5/utils/triton.py (deflated 68%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/dependabot.yml (deflated 54%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/docker.yml (deflated 67%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/links.yml (deflated 63%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/stale.yml (deflated 58%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/merge-main-into-prs.yml (deflated 66%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/format.yml (deflated 61%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/cla.yml (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/workflows/ci-testing.yml (deflated 71%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/bug-report.yml (deflated 60%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/config.yml (deflated 49%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/feature-request.yml (deflated 61%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.github/ISSUE_TEMPLATE/question.yml (deflated 56%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/yolov5m.pt (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/hubconf.py (deflated 82%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/export.py (deflated 73%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.gitattributes (deflated 4%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/CONTRIBUTING.md (deflated 57%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 45%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 10%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/train/exp/R_curve.png (deflated 17%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 8%)
#   adding: content/yolov5/yolov5/yolov5/yolov5
)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/post-update.sample (deflated 27%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/HEAD (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/remotes/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/tags/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/heads/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/refs/heads/master (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/info/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/info/exclude (deflated 28%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/HEAD (deflated 28%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/refs/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/refs/remotes/origin/HEAD (deflated 28%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/refs/heads/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/.git/logs/refs/heads/master (deflated 28%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/models/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/models/yolov5m.yaml (deflated 61%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/models/__pycache__/ (stored 0%)
#   adding: content/yolov5/yolov5/yolov5/yolov5/models/__pycache__/__init__.cpython-311.pyc (deflated 34%)
# ...
#   adding: content/yolov5/.git/logs/refs/ (stored 0%)
#   adding: content/yolov5/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/yolov5/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/yolov5/.git/logs/refs/remotes/origin/HEAD (deflated 28%)
#   adding: content/yolov5/.git/logs/refs/heads/ (stored 0%)
#   adding: content/yolov5/.git/logs/refs/heads/master (deflated 28%)
#   adding: content/yolov5/models/ (stored 0%)
#   adding: content/yolov5/models/yolov5m.yaml (deflated 61%)
#   adding: content/yolov5/models/__pycache__/ (stored 0%)
#   adding: content/yolov5/models/__pycache__/__init__.cpython-311.pyc (deflated 24%)
#   adding: content/yolov5/models/__pycache__/common.cpython-311.pyc (deflated 61%)
#   adding: content/yolov5/models/__pycache__/yolo.cpython-311.pyc (deflated 55%)
#   adding: content/yolov5/models/__pycache__/experimental.cpython-311.pyc (deflated 51%)
#   adding: content/yolov5/models/yolov5s.yaml (deflated 61%)
#   adding: content/yolov5/models/experimental.py (deflated 60%)
#   adding: content/yolov5/models/hub/ (stored 0%)
#   adding: content/yolov5/models/hub/yolov5-p6.yaml (deflated 66%)
#   adding: content/yolov5/models/hub/yolov5x6.yaml (deflated 65%)
#   adding: content/yolov5/models/hub/yolov5-panet.yaml (deflated 61%)
#   adding: content/yolov5/models/hub/anchors.yaml (deflated 66%)
#   adding: content/yolov5/models/hub/yolov5n6.yaml (deflated 65%)
#   adding: content/yolov5/models/hub/yolov3-spp.yaml (deflated 63%)
#   adding: content/yolov5/models/hub/yolov5-bifpn.yaml (deflated 60%)
#   adding: content/yolov5/models/hub/yolov3.yaml (deflated 64%)
#   adding: content/yolov5/models/hub/yolov5-p34.yaml (deflated 59%)
#   adding: content/yolov5/models/hub/yolov5s6.yaml (deflated 65%)
#   adding: content/yolov5/models/hub/yolov5-p2.yaml (deflated 66%)
#   adding: content/yolov5/models/hub/yolov5l6.yaml (deflated 65%)
#   adding: content/yolov5/models/hub/yolov5s-transformer.yaml (deflated 60%)
#   adding: content/yolov5/models/hub/yolov3-tiny.yaml (deflated 60%)
#   adding: content/yolov5/models/hub/yolov5s-LeakyReLU.yaml (deflated 59%)
#   adding: content/yolov5/models/hub/yolov5-p7.yaml (deflated 69%)
#   adding: content/yolov5/models/hub/yolov5m6.yaml (deflated 65%)
#   adding: content/yolov5/models/hub/yolov5-fpn.yaml (deflated 57%)
#   adding: content/yolov5/models/hub/yolov5s-ghost.yaml (deflated 62%)
#   adding: content/yolov5/models/yolov5l.yaml (deflated 61%)
#   adding: content/yolov5/models/yolov5n.yaml (deflated 61%)
#   adding: content/yolov5/models/tf.py (deflated 74%)
#   adding: content/yolov5/models/yolov5x.yaml (deflated 61%)
#   adding: content/yolov5/models/common.py (deflated 72%)
#   adding: content/yolov5/models/segment/ (stored 0%)
#   adding: content/yolov5/models/segment/yolov5n-seg.yaml (deflated 61%)
#   adding: content/yolov5/models/segment/yolov5l-seg.yaml (deflated 61%)
#   adding: content/yolov5/models/segment/yolov5x-seg.yaml (deflated 61%)
#   adding: content/yolov5/models/segment/yolov5s-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/segment/yolov5m-seg.yaml (deflated 60%)
#   adding: content/yolov5/models/__init__.py (deflated 14%)
#   adding: content/yolov5/models/yolo.py (deflated 67%)
#   adding: content/yolov5/tutorial.ipynb (deflated 74%)
#   adding: content/yolov5/detect.py (deflated 71%)
#   adding: content/yolov5/CITATION.cff (deflated 31%)
#   adding: content/yolov5/requirements.txt (deflated 56%)
#   adding: content/yolov5/wandb/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/run-379hytxf.wandb (deflated 86%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/wandb-metadata.json (deflated 51%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/output.log (deflated 94%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Results_50_b9c295192a14e9226208.png (deflated 17%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Validation_50_98437d771859ae1efcde.jpg (deflated 10%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Labels_0_e11534216d60a85c145e.jpg (deflated 45%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Mosaics_0_6df087d1c0822c1c4da3.jpg (deflated 7%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Mosaics_0_7e5cd50ae7124103a0c2.jpg (deflated 5%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Validation_50_9fbc3a9ac1788afd6bbe.jpg (deflated 11%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Results_50_09154642d400f052c85f.png (deflated 21%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Validation_50_713e749baa0b7343b41a.jpg (deflated 7%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Results_50_b04a32752eef5e0e3e5e.png (deflated 25%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Results_50_f855d5048d1563b68666.png (deflated 39%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Validation_50_06409e609d7b322158e1.jpg (deflated 7%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Results_50_beadf260df03c912c360.png (deflated 17%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Validation_50_7dad809ff22b9d0c0061.jpg (deflated 8%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Labels_0_2534e6b4b04cbf4c2048.jpg (deflated 44%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Results_50_dbc2c04a7142e375d8b5.png (deflated 9%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Mosaics_0_7d029712c68ff148135e.jpg (deflated 5%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/media/images/Validation_50_d8753cd49aaaca7eedfa.jpg (deflated 8%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/wandb-summary.json (deflated 64%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/config.yaml (deflated 70%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/files/requirements.txt (deflated 55%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/tmp/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/tmp/code/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/logs/ (stored 0%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/logs/debug-core.log (deflated 72%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/logs/debug.log (deflated 68%)
#   adding: content/yolov5/wandb/run-20250214_181902-379hytxf/logs/debug-internal.log (deflated 71%)
#   adding: content/yolov5/wandb/latest-run/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/run-379hytxf.wandb (deflated 86%)
#   adding: content/yolov5/wandb/latest-run/files/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/files/wandb-metadata.json (deflated 51%)
#   adding: content/yolov5/wandb/latest-run/files/output.log (deflated 94%)
#   adding: content/yolov5/wandb/latest-run/files/media/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Results_50_b9c295192a14e9226208.png (deflated 17%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Validation_50_98437d771859ae1efcde.jpg (deflated 10%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Labels_0_e11534216d60a85c145e.jpg (deflated 45%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Mosaics_0_6df087d1c0822c1c4da3.jpg (deflated 7%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Mosaics_0_7e5cd50ae7124103a0c2.jpg (deflated 5%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Validation_50_9fbc3a9ac1788afd6bbe.jpg (deflated 11%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Results_50_09154642d400f052c85f.png (deflated 21%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Validation_50_713e749baa0b7343b41a.jpg (deflated 7%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Results_50_b04a32752eef5e0e3e5e.png (deflated 25%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Results_50_f855d5048d1563b68666.png (deflated 39%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Validation_50_06409e609d7b322158e1.jpg (deflated 7%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Results_50_beadf260df03c912c360.png (deflated 17%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Validation_50_7dad809ff22b9d0c0061.jpg (deflated 8%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Labels_0_2534e6b4b04cbf4c2048.jpg (deflated 44%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Results_50_dbc2c04a7142e375d8b5.png (deflated 9%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Mosaics_0_7d029712c68ff148135e.jpg (deflated 5%)
#   adding: content/yolov5/wandb/latest-run/files/media/images/Validation_50_d8753cd49aaaca7eedfa.jpg (deflated 8%)
#   adding: content/yolov5/wandb/latest-run/files/wandb-summary.json (deflated 64%)
#   adding: content/yolov5/wandb/latest-run/files/config.yaml (deflated 70%)
#   adding: content/yolov5/wandb/latest-run/files/requirements.txt (deflated 55%)
#   adding: content/yolov5/wandb/latest-run/tmp/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/tmp/code/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/logs/ (stored 0%)
#   adding: content/yolov5/wandb/latest-run/logs/debug-core.log (deflated 72%)
#   adding: content/yolov5/wandb/latest-run/logs/debug.log (deflated 68%)
#   adding: content/yolov5/wandb/latest-run/logs/debug-internal.log (deflated 71%)
#   adding: content/yolov5/wandb/debug.log (deflated 68%)
#   adding: content/yolov5/wandb/debug-internal.log (deflated 71%)
#   adding: content/yolov5/benchmarks.py (deflated 73%)
#   adding: content/yolov5/README.md (deflated 78%)
#   adding: content/yolov5/LICENSE (deflated 66%)
#   adding: content/yolov5/utils/ (stored 0%)
#   adding: content/yolov5/utils/loss.py (deflated 69%)
#   adding: content/yolov5/utils/autoanchor.py (deflated 61%)
#   adding: content/yolov5/utils/loggers/ (stored 0%)
#   adding: content/yolov5/utils/loggers/__pycache__/ (stored 0%)
#   adding: content/yolov5/utils/loggers/__pycache__/__init__.cpython-311.pyc (deflated 57%)
#   adding: content/yolov5/utils/loggers/clearml/ (stored 0%)
#   adding: content/yolov5/utils/loggers/clearml/__pycache__/ (stored 0%)
#   adding: content/yolov5/utils/loggers/clearml/__pycache__/__init__.cpython-311.pyc (deflated 22%)
#   adding: content/yolov5/utils/loggers/clearml/__pycache__/clearml_utils.cpython-311.pyc (deflated 52%)
#   adding: content/yolov5/utils/loggers/clearml/clearml_utils.py (deflated 64%)
#   adding: content/yolov5/utils/loggers/clearml/__init__.py (deflated 14%)
#   adding: content/yolov5/utils/loggers/clearml/README.md (deflated 59%)
#   adding: content/yolov5/utils/loggers/clearml/hpo.py (deflated 70%)
#   adding: content/yolov5/utils/loggers/__init__.py (deflated 73%)
#   adding: content/yolov5/utils/loggers/wandb/ (stored 0%)
#   adding: content/yolov5/utils/loggers/wandb/wandb_utils.py (deflated 65%)
#   adding: content/yolov5/utils/loggers/wandb/__pycache__/ (stored 0%)
#   adding: content/yolov5/utils/loggers/wandb/__pycache__/__init__.cpython-311.pyc (deflated 22%)
#   adding: content/yolov5/utils/loggers/wandb/__pycache__/wandb_utils.cpython-311.pyc (deflated 50%)
#   adding: content/yolov5/utils/loggers/wandb/__init__.py (deflated 14%)
#   adding: content/yolov5/utils/loggers/comet/ (stored 0%)
#   adding: content/yolov5/utils/loggers/comet/optimizer_config.json (deflated 82%)
#   adding: content/yolov5/utils/loggers/comet/__pycache__/ (stored 0%)
#   adding: content/yolov5/utils/loggers/comet/__pycache__/__init__.cpython-311.pyc (deflated 55%)
#   adding: content/yolov5/utils/loggers/comet/__pycache__/comet_utils.cpython-311.pyc (deflated 51%)
#   adding: content/yolov5/utils/loggers/comet/__init__.py (deflated 74%)
#   adding: content/yolov5/utils/loggers/comet/README.md (deflated 64%)
#   adding: content/yolov5/utils/loggers/comet/comet_utils.py (deflated 69%)
#   adding: content/yolov5/utils/loggers/comet/hpo.py (deflated 67%)
#   adding: content/yolov5/utils/plots.py (deflated 64%)
#   adding: content/yolov5/utils/autobatch.py (deflated 56%)
#   adding: content/yolov5/utils/__pycache__/ (stored 0%)
#   adding: content/yolov5/utils/__pycache__/__init__.cpython-311.pyc (deflated 47%)
#   adding: content/yolov5/utils/__pycache__/autobatch.cpython-311.pyc (deflated 45%)
#   adding: content/yolov5/utils/__pycache__/general.cpython-311.pyc (deflated 55%)
#   adding: content/yolov5/utils/__pycache__/augmentations.cpython-311.pyc (deflated 54%)
#   adding: content/yolov5/utils/__pycache__/plots.cpython-311.pyc (deflated 53%)
#   adding: content/yolov5/utils/__pycache__/metrics.cpython-311.pyc (deflated 53%)
#   adding: content/yolov5/utils/__pycache__/autoanchor.cpython-311.pyc (deflated 50%)
#   adding: content/yolov5/utils/__pycache__/dataloaders.cpython-311.pyc (deflated 56%)
#   adding: content/yolov5/utils/__pycache__/torch_utils.cpython-311.pyc (deflated 53%)
#   adding: content/yolov5/utils/__pycache__/loss.cpython-311.pyc (deflated 54%)
#   adding: content/yolov5/utils/__pycache__/downloads.cpython-311.pyc (deflated 50%)
#   adding: content/yolov5/utils/__pycache__/callbacks.cpython-311.pyc (deflated 52%)
#   adding: content/yolov5/utils/downloads.py (deflated 62%)
#   adding: content/yolov5/utils/callbacks.py (deflated 68%)
#   adding: content/yolov5/utils/general.py (deflated 66%)
#   adding: content/yolov5/utils/augmentations.py (deflated 66%)
#   adding: content/yolov5/utils/torch_utils.py (deflated 64%)
#   adding: content/yolov5/utils/flask_rest_api/ (stored 0%)
#   adding: content/yolov5/utils/flask_rest_api/example_request.py (deflated 29%)
#   adding: content/yolov5/utils/flask_rest_api/restapi.py (deflated 49%)
#   adding: content/yolov5/utils/flask_rest_api/README.md (deflated 52%)
#   adding: content/yolov5/utils/activations.py (deflated 70%)
#   adding: content/yolov5/utils/google_app_engine/ (stored 0%)
#   adding: content/yolov5/utils/google_app_engine/additional_requirements.txt (deflated 41%)
#   adding: content/yolov5/utils/google_app_engine/Dockerfile (deflated 47%)
#   adding: content/yolov5/utils/google_app_engine/app.yaml (deflated 22%)
#   adding: content/yolov5/utils/docker/ (stored 0%)
#   adding: content/yolov5/utils/docker/Dockerfile-arm64 (deflated 51%)
#   adding: content/yolov5/utils/docker/Dockerfile-cpu (deflated 51%)
#   adding: content/yolov5/utils/docker/Dockerfile (deflated 55%)
#   adding: content/yolov5/utils/dataloaders.py (deflated 70%)
#   adding: content/yolov5/utils/segment/ (stored 0%)
#   adding: content/yolov5/utils/segment/loss.py (deflated 66%)
#   adding: content/yolov5/utils/segment/plots.py (deflated 63%)
#   adding: content/yolov5/utils/segment/general.py (deflated 70%)
#   adding: content/yolov5/utils/segment/augmentations.py (deflated 62%)
#   adding: content/yolov5/utils/segment/dataloaders.py (deflated 70%)
#   adding: content/yolov5/utils/segment/__init__.py (deflated 14%)
#   adding: content/yolov5/utils/segment/metrics.py (deflated 73%)
#   adding: content/yolov5/utils/__init__.py (deflated 57%)
#   adding: content/yolov5/utils/aws/ (stored 0%)
#   adding: content/yolov5/utils/aws/__init__.py (deflated 14%)
#   adding: content/yolov5/utils/aws/userdata.sh (deflated 47%)
#   adding: content/yolov5/utils/aws/mime.sh (deflated 46%)
#   adding: content/yolov5/utils/aws/resume.py (deflated 45%)
#   adding: content/yolov5/utils/metrics.py (deflated 66%)
#   adding: content/yolov5/utils/triton.py (deflated 68%)

# %%
# !mv yolov5.zip /content/drive/MyDrive/
